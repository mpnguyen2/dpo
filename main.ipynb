# %%
# Shape boundary train while exploring
# %load_ext autoreload 
# %autoreload 2 
from pmp_model import train_hnet_default_args
import time
start_time = time.time()
env_name = 'shape_boundary'
num_iter_arr = [5000] + [5000 for i in range(25)] + [10000]
sample_num_step_arr=[(i+1)*20 for i in range(27)]
train_hnet_default_args(env_name, sample_num_step_arr, num_iter_arr, net_type='objective')
print('Training takes {} seconds'.format(int(time.time()-start_time)))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Objective mode:
#
# Warming up net 0...
# Iter 500: loss 1.102.
# Iter 1000: loss 0.190.
# Iter 1500: loss 0.149.
# Iter 2000: loss 0.136.
# Iter 2500: loss 0.125.
# Iter 3000: loss 0.117.
# Iter 3500: loss 0.109.
# Iter 4000: loss 0.104.
# Iter 4500: loss 0.099.
# Iter 5000: loss 0.093.
#
# Warming up net 1...
# Iter 500: loss 0.136.
# Iter 1000: loss 0.117.
# Iter 1500: loss 0.110.
# Iter 2000: loss 0.104.
# Iter 2500: loss 0.098.
# Iter 3000: loss 0.094.
# Iter 3500: loss 0.090.
# Iter 4000: loss 0.087.
# Iter 4500: loss 0.083.
# Iter 5000: loss 0.079.
#
# Done warming up step.
#
#
#
# Sampling while optimizing in iter 1:
# [17.42024165]
# Memory size: 5016
#
# Optimzing net 0...
# Iter 500: loss 0.090.
# Iter 1000: loss 0.085.
# Iter 1500: loss 0.083.
# Iter 2000: loss 0.080.
# Iter 2500: loss 0.077.
# Iter 3000: loss 0.074.
# Iter 3500: loss 0.071.
# Iter 4000: loss 0.070.
# ...

# %%
# Test shape boundary (train while exploring)
# %load_ext autoreload
# %autoreload 2
from test import test_hnet

print(test_hnet(env_name='shape_boundary', mode='calculate_mean_reward', 
              num_traj=1000, sample_mode='random',
              rate=3e-3, net_type='objective', model_path_ext='_v1_',
              num_iter=500, step_size=3e-3))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 5.170963412598198

# %%
# Shape (with complex topo) train while exploring
# %load_ext autoreload 
# %autoreload 2 
from pmp_model import train_hnet_default_args
import time
start_time = time.time()
env_name = 'shape'
num_iter_arr = [5000] + [5000 for i in range(25)] + [10000]
sample_num_step_arr=[(i+1)*20 for i in range(27)]
train_hnet_default_args(env_name, sample_num_step_arr, num_iter_arr, net_type='objective')
print('Training takes {} seconds'.format(int(time.time()-start_time)))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Objective mode:
#
# Warming up net 0...
# Iter 500: loss 85.820.
# Iter 1000: loss 19.894.
# Iter 1500: loss 17.665.
# Iter 2000: loss 16.232.
# Iter 2500: loss 15.152.
# Iter 3000: loss 14.395.
# Iter 3500: loss 13.695.
# Iter 4000: loss 13.196.
# Iter 4500: loss 12.516.
# Iter 5000: loss 12.079.
#
# Warming up net 1...
# Iter 500: loss 589.215.
# Iter 1000: loss 99.171.
# Iter 1500: loss 95.044.
# Iter 2000: loss 90.347.
# Iter 2500: loss 87.732.
# Iter 3000: loss 84.463.
# Iter 3500: loss 81.750.
# Iter 4000: loss 79.342.
# Iter 4500: loss 76.633.
# Iter 5000: loss 74.159.
#
# Done warming up step.
#
#
#
# Sampling while optimizing in iter 1:
# [7.32816378]
# Memory size: 5016
#
# Optimzing net 0...
# Iter 500: loss 11.504.
# Iter 1000: loss 10.934.
# Iter 1500: loss 10.508.
# Iter 2000: loss 10.067.
# Iter 2500: loss 9.664.
# Iter 3000: loss 9.093.
# Iter 3500: loss 8.731.
# ...

# %%
# Test shape with complex topo (train while exploring)
# %load_ext autoreload
# %autoreload 2
from test import test_hnet
import warnings
warnings.filterwarnings("ignore")

print(test_hnet(env_name='shape', mode='calculate_mean_reward', 
              num_traj=1000, sample_mode='random',
              rate=3e-3, net_type='objective', model_path_ext='_v1_',
              num_iter=500, step_size=1e-3))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 5.112400769527962

# %%
# from test import simulate_pmp 
# simulate_pmp(env_name='molecule', rate=3e-3, num_iter=1000, step_size=1e-2, log_interval=10, show_interval=10)

# %%
# Train molecular energy
# %load_ext autoreload 
# %autoreload 2 
from pmp_model import train_hnet_default_args
import time
start_time = time.time()
env_name = 'molecule'
num_iter_arr = [5000] + [5000 for i in range(50)]
sample_num_step_arr=[(i+1)*20 for i in range(51)]
train_hnet_default_args(env_name, sample_num_step_arr, num_iter_arr)
print('Training takes {} seconds'.format(int(time.time()-start_time)))

# %%
# Test molecular energy
# %load_ext autoreload
# %autoreload 2
from test import test_hnet
import warnings
warnings.filterwarnings("ignore")

print(test_hnet(env_name='molecule', mode='calculate_mean_reward', 
              num_traj=1000, sample_mode='zero', add_noise=True,
              rate=3e-3, net_type='derivative', model_path_ext='_v1_',
              num_iter=1000, step_size=1e-2))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# core.scoring.ScoreFunctionFactory: SCOREFUNCTION: ref2015
# 17.025832549296666
