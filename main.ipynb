# %% [markdown]
# **TRAINING**

# %%
import sys
sys.path.append("/home/erickim/.pyrosetta/lib/python3.9/site-packages/pyrosetta-2025.13+release.80dd00bc09-py3.9-linux-x86_64.egg")

# %%
import pyrosetta
pyrosetta.init()
# Out:
# ┌──────────────────────────────────────────────────────────────────────────────┐
# │                                 PyRosetta-4                                  │
# │              Created in JHU by Sergey Lyskov and PyRosetta Team              │
# │              (C) Copyright Rosetta Commons Member Institutions               │
# │                                                                              │
# │ NOTE: USE OF PyRosetta FOR COMMERCIAL PURPOSES REQUIRE PURCHASE OF A LICENSE │
# │         See LICENSE.PyRosetta.md or email license@uw.edu for details         │
# └──────────────────────────────────────────────────────────────────────────────┘
# PyRosetta-4 2025 [Rosetta PyRosetta4.MinSizeRel.python39.ubuntu 2025.13+release.80dd00bc09d2543ce4b9a50f13c49219ee5cdd3b 2025-03-27T08:32:50] retrieved from: http://www.pyrosetta.org
# core.init: Checking for fconfig files in pwd and ./rosetta/flags
# core.init: Rosetta version: PyRosetta4.MinSizeRel.python39.ubuntu r396 2025.13+release.80dd00bc09 80dd00bc09d2543ce4b9a50f13c49219ee5cdd3b http://www.pyrosetta.org 2025-03-27T08:32:50
# core.init: Rosetta extras: []
# core.init: command: PyRosetta -ex1 -ex2aro -database /home/erickim/.pyrosetta/lib/python3.9/site-packages/pyrosetta-2025.13+release.80dd00bc09-py3.9-linux-x86_64.egg/pyrosetta/database
# basic.random.init_random_generator: 'RNG device' seed mode, using '/dev/urandom', seed=-963155939 seed_offset=0 real_seed=-963155939
# basic.random.init_random_generator: RandomGenerator:init: Normal mode, seed=-963155939 RG_type=mt19937

# %%
import sys
import numpy
print(sys.executable)
print(numpy.__version__)
# Out:
# /mnt/c/Users/DELL/dpo2/.venv/bin/python
# 1.26.4

# %%
from trains import train
import time
def train_helper(env_name, num_optimize_iters, warm_up_threshold, zero_order, save_interval):
    start_time = time.time()
    train(env_name, num_optimize_iters, warm_up_threshold, zero_order, save_interval)
    print('Training takes {} hours'.format(int(time.time()-start_time)/3600))
# Out:
# ┌──────────────────────────────────────────────────────────────────────────────┐
# │                                 PyRosetta-4                                  │
# │              Created in JHU by Sergey Lyskov and PyRosetta Team              │
# │              (C) Copyright Rosetta Commons Member Institutions               │
# │                                                                              │
# │ NOTE: USE OF PyRosetta FOR COMMERCIAL PURPOSES REQUIRE PURCHASE OF A LICENSE │
# │         See LICENSE.PyRosetta.md or email license@uw.edu for details         │
# └──────────────────────────────────────────────────────────────────────────────┘
# PyRosetta-4 2025 [Rosetta PyRosetta4.MinSizeRel.python39.ubuntu 2025.13+release.80dd00bc09d2543ce4b9a50f13c49219ee5cdd3b 2025-03-27T08:32:50] retrieved from: http://www.pyrosetta.org
# core.init: Checking for fconfig files in pwd and ./rosetta/flags
# core.init: Rosetta version: PyRosetta4.MinSizeRel.python39.ubuntu r396 2025.13+release.80dd00bc09 80dd00bc09d2543ce4b9a50f13c49219ee5cdd3b http://www.pyrosetta.org 2025-03-27T08:32:50
# core.init: Rosetta extras: []
# core.init: command: PyRosetta -ex1 -ex2aro -database /home/erickim/.pyrosetta/lib/python3.9/site-packages/pyrosetta-2025.13+release.80dd00bc09-py3.9-linux-x86_64.egg/pyrosetta/database
# basic.random.init_random_generator: 'RNG device' seed mode, using '/dev/urandom', seed=410919315 seed_offset=0 real_seed=410919315
# basic.random.init_random_generator: RandomGenerator:init: Normal mode, seed=410919315 RG_type=mt19937

# %%
# %reload_ext autoreload

# %% [markdown]
# **SHAPE**

# %%
# Shape boundary, zero order.
env_name = 'shape_boundary'
c = 1.05
num_optimize_iters = [int(10000 * (c**i)) for i in range(21)]
train_helper(env_name, num_optimize_iters, warm_up_threshold=15, zero_order=True, save_interval=5)
# Out:
# Hyperparams: Rate: 0.900, num traj: 128, step size: 0.01000, lr: 0.00100, batch_size: 32, log_interval:1000
#
#
# Currently at stage 0. Reinforce: False
# Iter 1000: loss 9.64273593.
# Iter 2000: loss 5.42365319.
# Iter 3000: loss 1.40725580.
# Iter 4000: loss 0.57586057.
# Iter 5000: loss 0.47969674.
# Iter 6000: loss 0.42189731.
# Iter 7000: loss 0.37034786.
# Iter 8000: loss 0.40319543.
# Iter 9000: loss 0.37307863.
# Iter 10000: loss 0.39282694.
#
#
# Currently at stage 1. Reinforce: False
# Iter 1000: loss 1.34446165.
# Iter 2000: loss 0.98563323.
# Iter 3000: loss 0.78215795.
# Iter 4000: loss 0.65035215.
# Iter 5000: loss 0.60773528.
# Iter 6000: loss 0.58482052.
# Iter 7000: loss 0.51605362.
# Iter 8000: loss 0.42744786.
# Iter 9000: loss 0.44472531.
# Iter 10000: loss 0.45114145.
#
#
# Currently at stage 2. Reinforce: False
# Iter 1000: loss 3.54364625.
# Iter 2000: loss 3.00220272.
# Iter 3000: loss 2.39643841.
# Iter 4000: loss 1.99874140.
# Iter 5000: loss 1.79327158.
# Iter 6000: loss 1.68775229.
# Iter 7000: loss 1.59826302.
# Iter 8000: loss 1.34204957.
# Iter 9000: loss 1.31158870.
# Iter 10000: loss 1.13492913.
# Iter 11000: loss 1.00728852.
#
#
# Currently at stage 3. Reinforce: False
# Iter 1000: loss 2.52354137.
# Iter 2000: loss 2.13064499.
# Iter 3000: loss 1.86353889.
# Iter 4000: loss 1.81811770.
# Iter 5000: loss 1.70761872.
# Iter 6000: loss 1.57414944.
# Iter 7000: loss 1.44119175.
# Iter 8000: loss 1.44055410.
# Iter 9000: loss 1.36083090.
# Iter 10000: loss 1.28356732.
# Iter 11000: loss 1.14077016.
#
#
# Currently at stage 4. Reinforce: False
# Iter 1000: loss 1.60611783.
# Iter 2000: loss 1.52691282.
# Iter 3000: loss 1.31890832.
# Iter 4000: loss 1.23236654.
# Iter 5000: loss 1.24219512.
# Iter 6000: loss 1.17118047.
# Iter 7000: loss 1.12863767.
# Iter 8000: loss 1.02978485.
# Iter 9000: loss 1.05353368.
# Iter 10000: loss 0.96292272.
# Iter 11000: loss 1.02233034.
# Iter 12000: loss 0.99273102.
#
#
# Currently at stage 5. Reinforce: False
# Iter 1000: loss 1.24915317.
# Iter 2000: loss 1.19489374.
# Iter 3000: loss 1.13829000.
# Iter 4000: loss 1.07394750.
# Iter 5000: loss 1.09304204.
# Iter 6000: loss 1.03589823.
# Iter 7000: loss 1.02304060.
# Iter 8000: loss 0.98573795.
# Iter 9000: loss 0.93216909.
# Iter 10000: loss 0.90691812.
# Iter 11000: loss 0.84291057.
# Iter 12000: loss 0.89662332.
#
#
# Currently at stage 6. Reinforce: False
# Iter 1000: loss 1.24442510.
# Iter 2000: loss 1.13811365.
# Iter 3000: loss 1.06106839.
# Iter 4000: loss 1.01828067.
# Iter 5000: loss 0.96073690.
# Iter 6000: loss 0.92408846.
# Iter 7000: loss 0.82673563.
# Iter 8000: loss 0.82742843.
# Iter 9000: loss 0.79377329.
# Iter 10000: loss 0.71833149.
# Iter 11000: loss 0.75999754.
# Iter 12000: loss 0.70693637.
# Iter 13000: loss 0.73368872.
#
#
# Currently at stage 7. Reinforce: False
# Iter 1000: loss 1.03495910.
# Iter 2000: loss 0.92472261.
# Iter 3000: loss 0.89300183.
# Iter 4000: loss 0.84191194.
# Iter 5000: loss 0.81801393.
# Iter 6000: loss 0.75785630.
# Iter 7000: loss 0.71913022.
# Iter 8000: loss 0.68778167.
# Iter 9000: loss 0.75044842.
# Iter 10000: loss 0.73407635.
# Iter 11000: loss 0.71751092.
# Iter 12000: loss 0.64668564.
# Iter 13000: loss 0.64787262.
# Iter 14000: loss 0.66340277.
#
#
# Currently at stage 8. Reinforce: False
# Iter 1000: loss 1.30587902.
# Iter 2000: loss 1.19445117.
# Iter 3000: loss 1.10069819.
# Iter 4000: loss 0.98533159.
# Iter 5000: loss 0.92395253.
# Iter 6000: loss 0.91255816.
# Iter 7000: loss 0.98598850.
# Iter 8000: loss 0.82804674.
# Iter 9000: loss 0.84213278.
# Iter 10000: loss 0.87551661.
# Iter 11000: loss 0.75834870.
# Iter 12000: loss 0.79237225.
# Iter 13000: loss 0.79219114.
# Iter 14000: loss 0.87499830.
#
#
# Currently at stage 9. Reinforce: False
# Iter 1000: loss 0.89044483.
# Iter 2000: loss 0.79896094.
# Iter 3000: loss 0.85486271.
# Iter 4000: loss 0.75641419.
# Iter 5000: loss 0.76130832.
# Iter 6000: loss 0.83953193.
# Iter 7000: loss 0.82297038.
# Iter 8000: loss 0.71514340.
# Iter 9000: loss 0.71251166.
# Iter 10000: loss 0.74308657.
# Iter 11000: loss 0.60862831.
# Iter 12000: loss 0.72029832.
# Iter 13000: loss 0.68479917.
# Iter 14000: loss 0.67812229.
# Iter 15000: loss 0.68408897.
#
#
# Currently at stage 10. Reinforce: False
# Iter 1000: loss 0.88214295.
# Iter 2000: loss 0.79599626.
# Iter 3000: loss 0.75732718.
# Iter 4000: loss 0.76621067.
# Iter 5000: loss 0.85706136.
# Iter 6000: loss 0.67087814.
# Iter 7000: loss 0.68425987.
# Iter 8000: loss 0.64690301.
# Iter 9000: loss 0.61707687.
# Iter 10000: loss 0.67866263.
# Iter 11000: loss 0.63225625.
# Iter 12000: loss 0.61773646.
# Iter 13000: loss 0.63971990.
# Iter 14000: loss 0.62241262.
# Iter 15000: loss 0.60056253.
# Iter 16000: loss 0.57750679.
#
#
# Currently at stage 11. Reinforce: False
# Iter 1000: loss 0.73166839.
# Iter 2000: loss 0.65756829.
# Iter 3000: loss 0.67352755.
# Iter 4000: loss 0.64869887.
# Iter 5000: loss 0.67113158.
# Iter 6000: loss 0.50498889.
# Iter 7000: loss 0.56301236.
# Iter 8000: loss 0.58537604.
# Iter 9000: loss 0.56285340.
# Iter 10000: loss 0.55653904.
# Iter 11000: loss 0.57965865.
# Iter 12000: loss 0.55921580.
# Iter 13000: loss 0.54808621.
# Iter 14000: loss 0.50554255.
# Iter 15000: loss 0.56141465.
# Iter 16000: loss 0.51280169.
# Iter 17000: loss 0.50908069.
#
#
# Currently at stage 12. Reinforce: False
# Iter 1000: loss 0.60303986.
# Iter 2000: loss 0.59987159.
# Iter 3000: loss 0.57138541.
# Iter 4000: loss 0.52594162.
# Iter 5000: loss 0.53925680.
# Iter 6000: loss 0.53158807.
# Iter 7000: loss 0.56105727.
# Iter 8000: loss 0.50881315.
# Iter 9000: loss 0.51802712.
# Iter 10000: loss 0.51123025.
# Iter 11000: loss 0.49653630.
# Iter 12000: loss 0.50629050.
# Iter 13000: loss 0.47061134.
# Iter 14000: loss 0.52891383.
# Iter 15000: loss 0.50307856.
# Iter 16000: loss 0.50149614.
# Iter 17000: loss 0.44976257.
#
#
# Currently at stage 13. Reinforce: False
# Iter 1000: loss 0.63742618.
# Iter 2000: loss 0.59743455.
# Iter 3000: loss 0.54587768.
# Iter 4000: loss 0.57460260.
# Iter 5000: loss 0.53021215.
# Iter 6000: loss 0.56177772.
# Iter 7000: loss 0.58766094.
# Iter 8000: loss 0.53254502.
# Iter 9000: loss 0.52860090.
# Iter 10000: loss 0.48417184.
# Iter 11000: loss 0.56083825.
# Iter 12000: loss 0.51801317.
# Iter 13000: loss 0.49656067.
# Iter 14000: loss 0.53595029.
# Iter 15000: loss 0.48057559.
# Iter 16000: loss 0.50212970.
# Iter 17000: loss 0.49979801.
# Iter 18000: loss 0.50613248.
#
#
# Currently at stage 14. Reinforce: False
# Iter 1000: loss 0.54994160.
# Iter 2000: loss 0.46901085.
# Iter 3000: loss 0.55488675.
# Iter 4000: loss 0.47225017.
# Iter 5000: loss 0.46504709.
# Iter 6000: loss 0.45106421.
# Iter 7000: loss 0.49287028.
# Iter 8000: loss 0.50040680.
# Iter 9000: loss 0.49235212.
# Iter 10000: loss 0.47623772.
# Iter 11000: loss 0.48467192.
# Iter 12000: loss 0.51105765.
# Iter 13000: loss 0.45949183.
# Iter 14000: loss 0.46634504.
# Iter 15000: loss 0.47299415.
# Iter 16000: loss 0.42009219.
# Iter 17000: loss 0.46622784.
# Iter 18000: loss 0.49752999.
# Iter 19000: loss 0.46778452.
#
#
# Currently at stage 15. Reinforce: True
# Iter 1000: loss 0.47876913.
# Iter 2000: loss 0.46924649.
# Iter 3000: loss 0.43242773.
# Iter 4000: loss 0.43904659.
# Iter 5000: loss 0.44795892.
# Iter 6000: loss 0.44820416.
# Iter 7000: loss 0.45826036.
# Iter 8000: loss 0.43193324.
# Iter 9000: loss 0.47605687.
# Iter 10000: loss 0.43254037.
# Iter 11000: loss 0.44972000.
# Iter 12000: loss 0.42014349.
# Iter 13000: loss 0.45680222.
# Iter 14000: loss 0.44056198.
# Iter 15000: loss 0.46390484.
# Iter 16000: loss 0.40017747.
# Iter 17000: loss 0.41163761.
# Iter 18000: loss 0.42862935.
# Iter 19000: loss 0.46484047.
# Iter 20000: loss 0.44905006.
#
#
# Currently at stage 16. Reinforce: True
# Iter 1000: loss 0.43717664.
# Iter 2000: loss 0.41938611.
# Iter 3000: loss 0.40706030.
# Iter 4000: loss 0.40362654.
# Iter 5000: loss 0.41194136.
# Iter 6000: loss 0.45836194.
# Iter 7000: loss 0.35224555.
# Iter 8000: loss 0.41432729.
# Iter 9000: loss 0.38338263.
# Iter 10000: loss 0.42402750.
# Iter 11000: loss 0.38833915.
# Iter 12000: loss 0.43236725.
# Iter 13000: loss 0.41224615.
# Iter 14000: loss 0.42821438.
# Iter 15000: loss 0.39372285.
# Iter 16000: loss 0.38021226.
# Iter 17000: loss 0.38278167.
# Iter 18000: loss 0.42593384.
# Iter 19000: loss 0.42531436.
# Iter 20000: loss 0.42994973.
# Iter 21000: loss 0.38137654.
#
#
# Currently at stage 17. Reinforce: True
# Iter 1000: loss 0.47412867.
# Iter 2000: loss 0.43375056.
# Iter 3000: loss 0.43592652.
# Iter 4000: loss 0.41769181.
# Iter 5000: loss 0.40606949.
# Iter 6000: loss 0.43574744.
# Iter 7000: loss 0.46248195.
# Iter 8000: loss 0.42178348.
# Iter 9000: loss 0.38288106.
# Iter 10000: loss 0.41679007.
# Iter 11000: loss 0.41293788.
# Iter 12000: loss 0.42756917.
# Iter 13000: loss 0.39081267.
# Iter 14000: loss 0.45204681.
# Iter 15000: loss 0.41562258.
# Iter 16000: loss 0.39972249.
# Iter 17000: loss 0.46741553.
# Iter 18000: loss 0.38880947.
# Iter 19000: loss 0.42029129.
# Iter 20000: loss 0.39982667.
# Iter 21000: loss 0.38524960.
# Iter 22000: loss 0.37446713.
#
#
# Currently at stage 18. Reinforce: True
# Iter 1000: loss 0.43551593.
# Iter 2000: loss 0.39781256.
# Iter 3000: loss 0.41612514.
# Iter 4000: loss 0.37737020.
# Iter 5000: loss 0.40700857.
# Iter 6000: loss 0.37431630.
# Iter 7000: loss 0.41464132.
# Iter 8000: loss 0.41954081.
# Iter 9000: loss 0.38595257.
# Iter 10000: loss 0.36483351.
# Iter 11000: loss 0.40423054.
# Iter 12000: loss 0.43846861.
# Iter 13000: loss 0.39264056.
# Iter 14000: loss 0.35176589.
# Iter 15000: loss 0.40344590.
# Iter 16000: loss 0.40149544.
# Iter 17000: loss 0.36901988.
# Iter 18000: loss 0.38312949.
# Iter 19000: loss 0.37776995.
# Iter 20000: loss 0.37536059.
# Iter 21000: loss 0.39036564.
# Iter 22000: loss 0.37215365.
# Iter 23000: loss 0.38705918.
# Iter 24000: loss 0.37834276.
#
#
# Currently at stage 19. Reinforce: True
# Iter 1000: loss 0.36280711.
# Iter 2000: loss 0.38216110.
# Iter 3000: loss 0.44686596.
# Iter 4000: loss 0.35431667.
# Iter 5000: loss 0.39934510.
# Iter 6000: loss 0.38694204.
# Iter 7000: loss 0.37252256.
# Iter 8000: loss 0.39158282.
# Iter 9000: loss 0.35011448.
# Iter 10000: loss 0.40315892.
# Iter 11000: loss 0.35524615.
# Iter 12000: loss 0.40444796.
# Iter 13000: loss 0.39929446.
# Iter 14000: loss 0.36969303.
# Iter 15000: loss 0.32798613.
# Iter 16000: loss 0.33569302.
# Iter 17000: loss 0.43416234.
# Iter 18000: loss 0.35193450.
# Iter 19000: loss 0.38796420.
# Iter 20000: loss 0.36421406.
# Iter 21000: loss 0.39283990.
# Iter 22000: loss 0.35505832.
# Iter 23000: loss 0.37670271.
# Iter 24000: loss 0.38902786.
# Iter 25000: loss 0.34193452.
#
#
# Currently at stage 20. Reinforce: True
# Iter 1000: loss 0.38857898.
# Iter 2000: loss 0.38945716.
# Iter 3000: loss 0.37460359.
# Iter 4000: loss 0.35002721.
# Iter 5000: loss 0.36030969.
# Iter 6000: loss 0.35166927.
# Iter 7000: loss 0.35195647.
# Iter 8000: loss 0.35169282.
# Iter 9000: loss 0.35910593.
# Iter 10000: loss 0.37948276.
# Iter 11000: loss 0.35261249.
# Iter 12000: loss 0.34233719.
# Iter 13000: loss 0.38798353.
# Iter 14000: loss 0.33353918.
# Iter 15000: loss 0.37180052.
# Iter 16000: loss 0.39838689.
# Iter 17000: loss 0.35094891.
# Iter 18000: loss 0.31399665.
# Iter 19000: loss 0.36896874.
# Iter 20000: loss 0.36484112.
# Iter 21000: loss 0.31356182.
# Iter 22000: loss 0.34598156.
# Iter 23000: loss 0.36576644.
# Iter 24000: loss 0.33627371.
# Iter 25000: loss 0.31912725.
# Iter 26000: loss 0.36089798.
#
# Done differential policy optimization training.
# Training takes 0.86 hours

# %%
# Shape boundary, first order.
env_name = 'shape_boundary'
c = 1.05
num_optimize_iters = [int(5000 * (c**i)) for i in range(21)]
train_helper(env_name, num_optimize_iters, warm_up_threshold=15, zero_order=False, save_interval=5)
# Out:
# Hyperparams: Rate: 0.900, num traj: 128, step size: 0.01000, lr: 0.00100, batch_size: 32, log_interval:1000
#
#
# Currently at stage 0. Reinforce: False
# Iter 1000: loss 356.10370677.
# Iter 2000: loss 319.43732404.
# Iter 3000: loss 312.20016542.
# Iter 4000: loss 267.77483666.
# Iter 5000: loss 261.26569660.
#
#
# Currently at stage 1. Reinforce: False
# Iter 1000: loss 116.44957028.
# Iter 2000: loss 120.82949841.
# Iter 3000: loss 99.06752815.
# Iter 4000: loss 100.17911401.
# Iter 5000: loss 87.77771096.
#
#
# Currently at stage 2. Reinforce: False
# Iter 1000: loss 72.44835695.
# Iter 2000: loss 64.93282834.
# Iter 3000: loss 74.75883249.
# Iter 4000: loss 87.76244600.
# Iter 5000: loss 81.38535449.
#
#
# Currently at stage 3. Reinforce: False
# Iter 1000: loss 152.76531611.
# Iter 2000: loss 180.50911678.
# Iter 3000: loss 160.00468995.
# Iter 4000: loss 165.89717453.
# Iter 5000: loss 170.93862877.
#
#
# Currently at stage 4. Reinforce: False
# Iter 1000: loss 115.68125762.
# Iter 2000: loss 119.62439049.
# Iter 3000: loss 109.84308313.
# Iter 4000: loss 159.71523786.
# Iter 5000: loss 127.23530369.
# Iter 6000: loss 106.84347599.
#
#
# Currently at stage 5. Reinforce: False
# Iter 1000: loss 79.17817481.
# Iter 2000: loss 94.72179563.
# Iter 3000: loss 91.86974453.
# Iter 4000: loss 89.06704843.
# Iter 5000: loss 97.70179749.
# Iter 6000: loss 69.58450092.
#
#
# Currently at stage 6. Reinforce: False
# Iter 1000: loss 108.84411909.
# Iter 2000: loss 87.69427051.
# Iter 3000: loss 81.26235002.
# Iter 4000: loss 81.40263271.
# Iter 5000: loss 81.32216823.
# Iter 6000: loss 94.77210090.
#
#
# Currently at stage 7. Reinforce: False
# Iter 1000: loss 77.74378716.
# Iter 2000: loss 73.87577887.
# Iter 3000: loss 52.40499350.
# Iter 4000: loss 59.57070298.
# Iter 5000: loss 68.01435444.
# Iter 6000: loss 65.08572971.
# Iter 7000: loss 73.70224594.
#
#
# Currently at stage 8. Reinforce: False
# Iter 1000: loss 65.44588677.
# Iter 2000: loss 62.71683294.
# Iter 3000: loss 50.12977965.
# Iter 4000: loss 61.84441283.
# Iter 5000: loss 86.41650797.
# Iter 6000: loss 69.16067587.
# Iter 7000: loss 67.01787237.
#
#
# Currently at stage 9. Reinforce: False
# Iter 1000: loss 70.81791068.
# Iter 2000: loss 58.55140802.
# Iter 3000: loss 61.16006449.
# Iter 4000: loss 45.27038403.
# Iter 5000: loss 45.44245116.
# Iter 6000: loss 53.13724231.
# Iter 7000: loss 64.55263517.
#
#
# Currently at stage 10. Reinforce: False
# Iter 1000: loss 62.62655168.
# Iter 2000: loss 45.77516940.
# Iter 3000: loss 45.54604288.
# Iter 4000: loss 56.21773392.
# Iter 5000: loss 58.11033112.
# Iter 6000: loss 32.87873904.
# Iter 7000: loss 68.41975355.
# Iter 8000: loss 43.57760444.
#
#
# Currently at stage 11. Reinforce: False
# Iter 1000: loss 38.63731092.
# Iter 2000: loss 62.46272240.
# Iter 3000: loss 44.83038175.
# Iter 4000: loss 51.76233912.
# Iter 5000: loss 54.13042561.
# Iter 6000: loss 50.99172122.
# Iter 7000: loss 29.96964230.
# Iter 8000: loss 76.43489676.
#
#
# Currently at stage 12. Reinforce: False
# Iter 1000: loss 50.48716208.
# Iter 2000: loss 39.67358492.
# Iter 3000: loss 45.02579957.
# Iter 4000: loss 41.58540562.
# Iter 5000: loss 36.65797641.
# Iter 6000: loss 46.06688013.
# Iter 7000: loss 46.86153966.
# Iter 8000: loss 43.08935696.
#
#
# Currently at stage 13. Reinforce: False
# Iter 1000: loss 32.37226676.
# Iter 2000: loss 50.83252950.
# Iter 3000: loss 24.36258729.
# Iter 4000: loss 47.75427364.
# Iter 5000: loss 47.92505722.
# Iter 6000: loss 54.82411539.
# Iter 7000: loss 43.73720570.
# Iter 8000: loss 61.34615313.
# Iter 9000: loss 31.09296668.
#
#
# Currently at stage 14. Reinforce: False
# Iter 1000: loss 40.05148120.
# Iter 2000: loss 36.55428074.
# Iter 3000: loss 32.40411097.
# Iter 4000: loss 31.45021078.
# Iter 5000: loss 41.51834013.
# Iter 6000: loss 43.35861967.
# Iter 7000: loss 31.65032101.
# Iter 8000: loss 45.18511040.
# Iter 9000: loss 40.30048062.
#
#
# Currently at stage 15. Reinforce: True
# Iter 1000: loss 37.72256131.
# Iter 2000: loss 33.85021402.
# Iter 3000: loss 27.03337004.
# Iter 4000: loss 37.51080192.
# Iter 5000: loss 38.35142038.
# Iter 6000: loss 15.52217175.
# Iter 7000: loss 30.75158123.
# Iter 8000: loss 30.77326568.
# Iter 9000: loss 35.34437858.
# Iter 10000: loss 30.44445513.
#
#
# Currently at stage 16. Reinforce: True
# Iter 1000: loss 23.04537801.
# Iter 2000: loss 42.27568460.
# Iter 3000: loss 36.07942564.
# Iter 4000: loss 15.84719382.
# Iter 5000: loss 15.63747408.
# Iter 6000: loss 40.14465117.
# Iter 7000: loss 19.40873083.
# Iter 8000: loss 38.27806892.
# Iter 9000: loss 25.36360172.
# Iter 10000: loss 29.13203197.
#
#
# Currently at stage 17. Reinforce: True
# Iter 1000: loss 18.62301196.
# Iter 2000: loss 22.97382489.
# Iter 3000: loss 28.28946544.
# Iter 4000: loss 28.44086044.
# Iter 5000: loss 25.72006446.
# Iter 6000: loss 36.25993545.
# Iter 7000: loss 28.69429885.
# Iter 8000: loss 23.31148293.
# Iter 9000: loss 35.16525926.
# Iter 10000: loss 33.47772341.
# Iter 11000: loss 19.35803751.
#
#
# Currently at stage 18. Reinforce: True
# Iter 1000: loss 22.42277345.
# Iter 2000: loss 28.88015264.
# Iter 3000: loss 21.67907850.
# Iter 4000: loss 18.16164249.
# Iter 5000: loss 34.61892512.
# Iter 6000: loss 23.89755428.
# Iter 7000: loss 25.75668684.
# Iter 8000: loss 13.53158819.
# Iter 9000: loss 21.19572671.
# Iter 10000: loss 24.81715362.
# Iter 11000: loss 17.44438211.
# Iter 12000: loss 24.52248015.
#
#
# Currently at stage 19. Reinforce: True
# Iter 1000: loss 18.37265747.
# Iter 2000: loss 22.19806885.
# Iter 3000: loss 15.89325446.
# Iter 4000: loss 22.74812190.
# Iter 5000: loss 16.99756885.
# Iter 6000: loss 19.81125267.
# Iter 7000: loss 27.45990394.
# Iter 8000: loss 18.35162886.
# Iter 9000: loss 27.72888080.
# Iter 10000: loss 29.88686359.
# Iter 11000: loss 15.51995177.
# Iter 12000: loss 26.80364575.
#
#
# Currently at stage 20. Reinforce: True
# Iter 1000: loss 12.62469991.
# Iter 2000: loss 27.21039137.
# Iter 3000: loss 21.79035370.
# Iter 4000: loss 22.11436609.
# Iter 5000: loss 20.83231719.
# Iter 6000: loss 29.33045729.
# Iter 7000: loss 17.97772773.
# Iter 8000: loss 12.99329185.
# Iter 9000: loss 12.73893035.
# Iter 10000: loss 24.68855795.
# Iter 11000: loss 26.67063439.
# Iter 12000: loss 15.10815788.
# Iter 13000: loss 16.22995065.
#
# Done differential policy optimization training.
# Training takes 0.42138888888888887 hours

# %% [markdown]
# **SHAPE WITH TOPO**

# %%
# Shape, zero order.
env_name = 'shape'
c = 1.05
num_optimize_iters = [int(10000 * (c**i)) for i in range(21)]
train_helper(env_name, num_optimize_iters, warm_up_threshold=15, zero_order=True, save_interval=5)

# %%
# Shape, first order.
env_name = 'shape'
c = 1.05
num_optimize_iters = [int(5000 * (c**i)) for i in range(21)]
train_helper(env_name, num_optimize_iters, warm_up_threshold=15, zero_order=False, save_interval=5)

# %% [markdown]
# **MOLECULE**

# %%
from train import train
import time
def train_helper(env_name, num_optimize_iters, warm_up_threshold, zero_order, save_interval):
    start_time = time.time()
    train(env_name, num_optimize_iters, warm_up_threshold, zero_order, save_interval)
    print('Training takes {} hours'.format(int(time.time()-start_time)/3600))

# %%
# Molecule zero order.
env_name = 'molecule'
c = 1.5
num_optimize_iters = [int(1000 * (c**i)) for i in range(10)]
train_helper(env_name, num_optimize_iters, warm_up_threshold=5, zero_order=True, save_interval=5)

# %%
# Molecule first order.
env_name = 'molecule'
c = 1.5
num_optimize_iters = [int(1000 * (c**i)) for i in range(10)]
train_helper(env_name, num_optimize_iters, warm_up_threshold=5, zero_order=False, save_interval=5)

# %% [markdown]
# **VISUALIZATION**

# %%
from test import visualize
from utils import get_environment
from benchmarks.sb3_utils import setup_benchmark_model

# %%
# Visualization from benchmark
env_name = 'molecule'
env = get_environment(env_name)
method='SAC'
model = setup_benchmark_model(method, env, env_name)
visualize(env, model, num_step=100, benchmark_model=True,
              extra_args='random', img_path=None)
