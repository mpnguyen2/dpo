# %% [markdown]
# **TRAINING**

# %%
from train import train
import time
def train_helper(env_name, num_optimize_iters, warm_up_threshold, zero_order, save_interval):
    start_time = time.time()
    train(env_name, num_optimize_iters, warm_up_threshold, zero_order, save_interval)
    print('Training takes {} hours'.format(int(time.time()-start_time)/3600))
# Out:
# PyRosetta-4 2023 [Rosetta PyRosetta4.Release.python39.linux 2023.12+release.1d8714894eec1dac6443b64d144d220c4aed4f9c 2023-03-20T20:16:16] retrieved from: http://www.pyrosetta.org
# (C) Copyright Rosetta Commons Member Institutions. Created in JHU by Sergey Lyskov and PyRosetta Team.
# core.init: Checking for fconfig files in pwd and ./rosetta/flags
# core.init: Rosetta version: PyRosetta4.Release.python39.linux r343 2023.12+release.1d87148 1d8714894eec1dac6443b64d144d220c4aed4f9c http://www.pyrosetta.org 2023-03-20T20:16:16
# core.init: command: PyRosetta -ex1 -ex2aro -database /home/mpnguyen/anaconda3/envs/basics/lib/python3.9/site-packages/pyrosetta/database
# basic.random.init_random_generator: 'RNG device' seed mode, using '/dev/urandom', seed=-1806257503 seed_offset=0 real_seed=-1806257503
# basic.random.init_random_generator: RandomGenerator:init: Normal mode, seed=-1806257503 RG_type=mt19937

# %%
# %reload_ext autoreload

# %% [markdown]
# **SHAPE**

# %%
# Shape boundary, zero order.
env_name = 'shape_boundary'
c = 1.05
num_optimize_iters = [int(10000 * (c**i)) for i in range(21)]
train_helper(env_name, num_optimize_iters, warm_up_threshold=15, zero_order=True, save_interval=5)
# Out:
# Hyperparams: Rate: 1.000, num traj: 128, step size: 0.01000, lr: 0.00100, batch_size: 32, log_interval:1000
#
#
# Currently at stage 0. Reinforce: False
# Iter 1000: loss 6.749.
# Iter 2000: loss 1.814.
# Iter 3000: loss 0.817.
# Iter 4000: loss 0.607.
# Iter 5000: loss 0.528.
# Iter 6000: loss 0.437.
# Iter 7000: loss 0.408.
# Iter 8000: loss 0.389.
# Iter 9000: loss 0.383.
# Iter 10000: loss 0.353.
#
#
# Currently at stage 1. Reinforce: False
# Iter 1000: loss 2.302.
# Iter 2000: loss 1.585.
# Iter 3000: loss 1.437.
# Iter 4000: loss 1.328.
# Iter 5000: loss 1.184.
# Iter 6000: loss 1.125.
# Iter 7000: loss 1.176.
# Iter 8000: loss 1.070.
# Iter 9000: loss 1.009.
# Iter 10000: loss 0.989.
#
#
# Currently at stage 2. Reinforce: False
# Iter 1000: loss 3.644.
# Iter 2000: loss 2.740.
# Iter 3000: loss 2.317.
# Iter 4000: loss 1.888.
# Iter 5000: loss 1.563.
# Iter 6000: loss 1.589.
# Iter 7000: loss 1.295.
# Iter 8000: loss 1.253.
# Iter 9000: loss 1.206.
# Iter 10000: loss 1.113.
# Iter 11000: loss 1.081.
#
#
# Currently at stage 3. Reinforce: False
# Iter 1000: loss 2.275.
# Iter 2000: loss 1.976.
# Iter 3000: loss 1.510.
# Iter 4000: loss 1.562.
# Iter 5000: loss 1.569.
# Iter 6000: loss 1.187.
# Iter 7000: loss 1.204.
# Iter 8000: loss 1.004.
# Iter 9000: loss 1.000.
# Iter 10000: loss 0.932.
# Iter 11000: loss 0.846.
#
#
# Currently at stage 4. Reinforce: False
# Iter 1000: loss 1.459.
# Iter 2000: loss 1.344.
# Iter 3000: loss 1.153.
# Iter 4000: loss 0.948.
# Iter 5000: loss 0.967.
# Iter 6000: loss 0.972.
# Iter 7000: loss 0.897.
# Iter 8000: loss 0.832.
# Iter 9000: loss 1.022.
# Iter 10000: loss 0.733.
# Iter 11000: loss 0.788.
# Iter 12000: loss 0.725.
#
#
# Currently at stage 5. Reinforce: False
# Iter 1000: loss 1.220.
# Iter 2000: loss 1.169.
# Iter 3000: loss 0.969.
# Iter 4000: loss 0.976.
# Iter 5000: loss 0.982.
# Iter 6000: loss 0.901.
# Iter 7000: loss 0.829.
# Iter 8000: loss 1.035.
# Iter 9000: loss 0.851.
# Iter 10000: loss 0.756.
# Iter 11000: loss 0.815.
# Iter 12000: loss 0.894.
#
#
# Currently at stage 6. Reinforce: False
# Iter 1000: loss 1.217.
# Iter 2000: loss 0.890.
# Iter 3000: loss 1.055.
# Iter 4000: loss 0.959.
# Iter 5000: loss 0.933.
# Iter 6000: loss 0.830.
# Iter 7000: loss 0.817.
# Iter 8000: loss 0.852.
# Iter 9000: loss 0.789.
# Iter 10000: loss 0.888.
# Iter 11000: loss 0.641.
# Iter 12000: loss 0.852.
# Iter 13000: loss 0.745.
#
#
# Currently at stage 7. Reinforce: False
# Iter 1000: loss 0.919.
# Iter 2000: loss 0.836.
# Iter 3000: loss 0.908.
# Iter 4000: loss 0.817.
# Iter 5000: loss 0.606.
# Iter 6000: loss 0.724.
# Iter 7000: loss 0.624.
# Iter 8000: loss 0.719.
# Iter 9000: loss 0.813.
# Iter 10000: loss 0.677.
# Iter 11000: loss 0.640.
# Iter 12000: loss 0.777.
# Iter 13000: loss 0.630.
# Iter 14000: loss 0.719.
#
#
# Currently at stage 8. Reinforce: False
# Iter 1000: loss 0.979.
# Iter 2000: loss 0.979.
# Iter 3000: loss 1.028.
# Iter 4000: loss 0.863.
# Iter 5000: loss 0.832.
# Iter 6000: loss 0.827.
# Iter 7000: loss 0.874.
# Iter 8000: loss 0.908.
# Iter 9000: loss 0.737.
# Iter 10000: loss 0.750.
# Iter 11000: loss 0.925.
# Iter 12000: loss 0.783.
# Iter 13000: loss 0.711.
# Iter 14000: loss 0.744.
#
#
# Currently at stage 9. Reinforce: False
# Iter 1000: loss 0.815.
# Iter 2000: loss 0.685.
# Iter 3000: loss 0.755.
# Iter 4000: loss 0.642.
# Iter 5000: loss 0.642.
# Iter 6000: loss 0.580.
# Iter 7000: loss 0.708.
# Iter 8000: loss 0.667.
# Iter 9000: loss 0.619.
# Iter 10000: loss 0.634.
# Iter 11000: loss 0.759.
# Iter 12000: loss 0.590.
# Iter 13000: loss 0.600.
# Iter 14000: loss 0.673.
# Iter 15000: loss 0.688.
#
#
# Currently at stage 10. Reinforce: False
# Iter 1000: loss 0.763.
# Iter 2000: loss 0.810.
# Iter 3000: loss 0.732.
# Iter 4000: loss 0.613.
# Iter 5000: loss 0.724.
# Iter 6000: loss 0.636.
# Iter 7000: loss 0.616.
# Iter 8000: loss 0.612.
# Iter 9000: loss 0.692.
# Iter 10000: loss 0.617.
# Iter 11000: loss 0.659.
# Iter 12000: loss 0.695.
# Iter 13000: loss 0.647.
# Iter 14000: loss 0.600.
# Iter 15000: loss 0.582.
# Iter 16000: loss 0.642.
#
#
# Currently at stage 11. Reinforce: False
# Iter 1000: loss 0.738.
# Iter 2000: loss 0.719.
# Iter 3000: loss 0.629.
# Iter 4000: loss 0.634.
# Iter 5000: loss 0.643.
# Iter 6000: loss 0.572.
# Iter 7000: loss 0.728.
# Iter 8000: loss 0.686.
# Iter 9000: loss 0.600.
# Iter 10000: loss 0.649.
# Iter 11000: loss 0.610.
# Iter 12000: loss 0.579.
# Iter 13000: loss 0.571.
# Iter 14000: loss 0.531.
# Iter 15000: loss 0.597.
# Iter 16000: loss 0.529.
# Iter 17000: loss 0.555.
#
#
# Currently at stage 12. Reinforce: False
# Iter 1000: loss 0.604.
# Iter 2000: loss 0.680.
# Iter 3000: loss 0.524.
# Iter 4000: loss 0.567.
# Iter 5000: loss 0.560.
# Iter 6000: loss 0.586.
# Iter 7000: loss 0.534.
# Iter 8000: loss 0.543.
# Iter 9000: loss 0.541.
# Iter 10000: loss 0.555.
# Iter 11000: loss 0.531.
# Iter 12000: loss 0.567.
# Iter 13000: loss 0.517.
# Iter 14000: loss 0.514.
# Iter 15000: loss 0.548.
# Iter 16000: loss 0.462.
# Iter 17000: loss 0.463.
#
#
# Currently at stage 13. Reinforce: False
# Iter 1000: loss 0.506.
# Iter 2000: loss 0.557.
# Iter 3000: loss 0.480.
# Iter 4000: loss 0.486.
# Iter 5000: loss 0.558.
# Iter 6000: loss 0.490.
# Iter 7000: loss 0.414.
# Iter 8000: loss 0.501.
# Iter 9000: loss 0.488.
# Iter 10000: loss 0.491.
# Iter 11000: loss 0.532.
# Iter 12000: loss 0.447.
# Iter 13000: loss 0.499.
# Iter 14000: loss 0.372.
# Iter 15000: loss 0.472.
# Iter 16000: loss 0.470.
# Iter 17000: loss 0.483.
# Iter 18000: loss 0.432.
#
#
# Currently at stage 14. Reinforce: False
# Iter 1000: loss 0.479.
# Iter 2000: loss 0.492.
# Iter 3000: loss 0.437.
# Iter 4000: loss 0.478.
# Iter 5000: loss 0.487.
# Iter 6000: loss 0.436.
# Iter 7000: loss 0.466.
# Iter 8000: loss 0.483.
# Iter 9000: loss 0.400.
# Iter 10000: loss 0.422.
# Iter 11000: loss 0.425.
# Iter 12000: loss 0.446.
# Iter 13000: loss 0.465.
# Iter 14000: loss 0.426.
# Iter 15000: loss 0.396.
# Iter 16000: loss 0.434.
# Iter 17000: loss 0.355.
# Iter 18000: loss 0.437.
# Iter 19000: loss 0.392.
#
#
# Currently at stage 15. Reinforce: True
# Iter 1000: loss 0.506.
# Iter 2000: loss 0.416.
# Iter 3000: loss 0.465.
# Iter 4000: loss 0.499.
# Iter 5000: loss 0.417.
# Iter 6000: loss 0.430.
# Iter 7000: loss 0.451.
# Iter 8000: loss 0.415.
# Iter 9000: loss 0.426.
# Iter 10000: loss 0.422.
# Iter 11000: loss 0.392.
# Iter 12000: loss 0.455.
# Iter 13000: loss 0.422.
# Iter 14000: loss 0.394.
# Iter 15000: loss 0.418.
# Iter 16000: loss 0.393.
# Iter 17000: loss 0.417.
# Iter 18000: loss 0.428.
# Iter 19000: loss 0.370.
# Iter 20000: loss 0.402.
#
#
# Currently at stage 16. Reinforce: True
# Iter 1000: loss 0.433.
# Iter 2000: loss 0.392.
# Iter 3000: loss 0.452.
# Iter 4000: loss 0.379.
# Iter 5000: loss 0.415.
# Iter 6000: loss 0.368.
# Iter 7000: loss 0.428.
# Iter 8000: loss 0.406.
# Iter 9000: loss 0.430.
# Iter 10000: loss 0.422.
# Iter 11000: loss 0.375.
# Iter 12000: loss 0.341.
# Iter 13000: loss 0.446.
# Iter 14000: loss 0.339.
# Iter 15000: loss 0.396.
# Iter 16000: loss 0.400.
# Iter 17000: loss 0.376.

# %%
# Shape boundary, first order.
env_name = 'shape_boundary'
c = 1.05
num_optimize_iters = [int(5000 * (c**i)) for i in range(21)]
train_helper(env_name, num_optimize_iters, warm_up_threshold=15, zero_order=False, save_interval=5)

# %% [markdown]
# **SHAPE WITH TOPO**

# %%
# Shape, zero order.
env_name = 'shape'
c = 1.05
num_optimize_iters = [int(10000 * (c**i)) for i in range(21)]
train_helper(env_name, num_optimize_iters, warm_up_threshold=15, zero_order=True, save_interval=5)

# %%
# Shape, first order.
env_name = 'shape'
c = 1.05
num_optimize_iters = [int(5000 * (c**i)) for i in range(21)]
train_helper(env_name, num_optimize_iters, warm_up_threshold=15, zero_order=False, save_interval=5)

# %% [markdown]
# **MOLECULE**

# %%
from train import train
import time
def train_helper(env_name, num_optimize_iters, warm_up_threshold, zero_order, save_interval):
    start_time = time.time()
    train(env_name, num_optimize_iters, warm_up_threshold, zero_order, save_interval)
    print('Training takes {} hours'.format(int(time.time()-start_time)/3600))

# %%
# Molecule zero order.
env_name = 'molecule'
c = 1.5
num_optimize_iters = [int(1000 * (c**i)) for i in range(10)]
train_helper(env_name, num_optimize_iters, warm_up_threshold=5, zero_order=True, save_interval=5)

# %%
# Molecule first order.
env_name = 'molecule'
c = 1.5
num_optimize_iters = [int(1000 * (c**i)) for i in range(10)]
train_helper(env_name, num_optimize_iters, warm_up_threshold=5, zero_order=False, save_interval=5)

# %% [markdown]
# **VISUALIZATION**

# %%
from test import visualize
from utils import get_environment
from benchmarks.sb3_utils import setup_benchmark_model

# %%
# Visualization from benchmark
env_name = 'molecule'
env = get_environment(env_name)
method='SAC'
model = setup_benchmark_model(method, env, env_name)
visualize(env, model, num_step=100, benchmark_model=True,
              extra_args='random', img_path=None)
